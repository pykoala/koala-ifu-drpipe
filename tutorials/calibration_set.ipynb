# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from koala_drpipe.calibration import CalibrationSet

# %%
calset = CalibrationSet.from_config_yml("config_example_blue_arm.yml")
# Out:
# [pykoala.koala-dr-pipe] 2025/03/31 18:05|INFO> Initialising Corrections from config file
# [pykoala] 2025/03/31 18:05|INFO>
# > Reading KOALA RSS file 27feb10009red.fits
# [pykoala] 2025/03/31 18:05|INFO> No. of fibres in this RSS =1000
# No. of good fibres = 986
# No. of bad fibres = 14
# [pykoala] 2025/03/31 18:05|INFO> Bad fibres = [109, 110, 235, 424, 574, 607, 675, 714, 721, 722, 723, 793, 950, 951]
# WARNING: VerifyWarning: Keyword name 'RADECSYSa' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'Angstroms' -> 'Angstrom'. [astropy.wcs.wcs]
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1095: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)
# Applying median filter (size=20 px)
# [pykoala.correction.AtmosphericExtinction] 2025/03/31 18:05|INFO> Initialising correction
# [pykoala.koala-dr-pipe] 2025/03/31 18:05|INFO> Preparing calibrations from standard stars
# [pykoala] 2025/03/31 18:05|INFO>
# > Reading KOALA RSS file 27feb10028red.fits
# [pykoala] 2025/03/31 18:05|INFO> No. of fibres in this RSS =1000
# No. of good fibres = 986
# No. of bad fibres = 14
# [pykoala] 2025/03/31 18:05|INFO> Bad fibres = [109, 110, 235, 424, 574, 607, 675, 714, 721, 722, 723, 793, 950, 951]
# [pykoala] 2025/03/31 18:05|INFO>
# > Reading KOALA RSS file 27feb10029red.fits
# [pykoala] 2025/03/31 18:05|INFO> No. of fibres in this RSS =1000
# No. of good fibres = 986
# No. of bad fibres = 14
# [pykoala] 2025/03/31 18:05|INFO> Bad fibres = [109, 110, 235, 424, 574, 607, 675, 714, 721, 722, 723, 793, 950, 951]
# [pykoala] 2025/03/31 18:05|INFO>
# > Reading KOALA RSS file 27feb10030red.fits
# [pykoala] 2025/03/31 18:05|INFO> No. of fibres in this RSS =1000
# No. of good fibres = 986
# No. of bad fibres = 14
# [pykoala] 2025/03/31 18:05|INFO> Bad fibres = [109, 110, 235, 424, 574, 607, 675, 714, 721, 722, 723, 793, 950, 951]
# [pykoala.koala-dr-pipe] 2025/03/31 18:05|INFO> Number of input std. stars: 3
# [pykoala.koala-dr-pipe] 2025/03/31 18:05|INFO> Applying ThroughputCorrection to RSS
# [pykoala.koala-dr-pipe] 2025/03/31 18:05|INFO> Applying AtmosphericExtinctionCorrection to RSS
# [pykoala.correction.AtmosphericExtinction] 2025/03/31 18:05|INFO> Applying model-based extinction correction toData Container (1.23 airmass)
# [pykoala.correction.AtmosphericExtinction] 2025/03/31 18:05|INFO> Applying model-based extinction correction toData Container (1.22 airmass)
# [pykoala.correction.AtmosphericExtinction] 2025/03/31 18:05|INFO> Applying model-based extinction correction toData Container (1.22 airmass)
# WARNING: VerifyWarning: Keyword name 'RADECSYSa' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'Angstroms' -> 'Angstrom'. [astropy.wcs.wcs]
# WARNING: VerifyWarning: Keyword name 'RADECSYSa' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'Angstroms' -> 'Angstrom'. [astropy.wcs.wcs]
# WARNING: VerifyWarning: Keyword name 'RADECSYSa' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'Angstroms' -> 'Angstrom'. [astropy.wcs.wcs]
# [pykoala] 2025/03/31 18:05|INFO> Creating SkyModel from input Data Container
# [pykoala] 2025/03/31 18:05|INFO> Estimating sky background contribution...
# [pykoala] 2025/03/31 18:05|INFO> Pre-estimating background using all data
# [pykoala] 2025/03/31 18:05|INFO> Applying sigma-clipping mask (n-sigma=3)
# [pykoala.correction.SkyCorrection] 2025/03/31 18:05|INFO> Applying sky subtraction
# [pykoala] 2025/03/31 18:05|INFO> Creating SkyModel from input Data Container
# [pykoala] 2025/03/31 18:05|INFO> Estimating sky background contribution...
# [pykoala] 2025/03/31 18:05|INFO> Pre-estimating background using all data
# [pykoala] 2025/03/31 18:05|INFO> Applying sigma-clipping mask (n-sigma=3)
# [pykoala.correction.SkyCorrection] 2025/03/31 18:05|INFO> Applying sky subtraction
# [pykoala] 2025/03/31 18:05|INFO> Creating SkyModel from input Data Container
# [pykoala] 2025/03/31 18:05|INFO> Estimating sky background contribution...
# [pykoala] 2025/03/31 18:05|INFO> Pre-estimating background using all data
# [pykoala] 2025/03/31 18:05|INFO> Applying sigma-clipping mask (n-sigma=3)
# [pykoala.correction.SkyCorrection] 2025/03/31 18:05|INFO> Applying sky subtraction
# [pykoala.correction.Astrometry] 2025/03/31 18:05|INFO> Reference position: RA=101.30571895 deg, DEC=2.13741257 deg)
# [pykoala] 2025/03/31 18:05|INFO> [Registration]  Data provided in RSS format --> creating a dummy datacube
# [pykoala] 2025/03/31 18:05|INFO> Combined footprint center: 101.3049 deg, 2.1383 deg
# [pykoala] 2025/03/31 18:05|INFO> Combined footprint Fov: 0.43 arcmin, 0.82 arcmin (arcmin)
# [pykoala] 2025/03/31 18:05|INFO> Combined footprint wavelength range: 3632.2 Angstrom, 5760.5 Angstrom (AA)
# [pykoala] 2025/03/31 18:05|INFO> WCS array shape: (2047, 52, 99) [wave, ra, dec]
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Using input WCS
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Initialising GaussianKernel
#  Scale: 1.0 arcsec (pixels)
#  Truncation radius: 3.0 (3.0 arcsec px)
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Initialising new Cube with dimensions: (2047, 99, 52)
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Output Cube units: adu / s
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Cubing input RSS set
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Interpolating RSS to cube
# [pykoala.CubeInterp] 2025/03/31 18:05|INFO> Fibres will be interpolated to new wavelength grid
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'angstrom' -> 'Angstrom'. [astropy.wcs.wcs]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Stacking individual cubes using mad_clipping
# [pykoala] 2025/03/31 18:06|INFO> Only one cube to stack
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Offset found (ra, dec): 3.0305439461983497-2.5172618468371155 (arcsec)
# [pykoala] 2025/03/31 18:06|INFO> [Registration]  Data provided in RSS format --> creating a dummy datacube
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint center: 101.3049 deg, 2.1375 deg
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint Fov: 0.43 arcmin, 0.82 arcmin (arcmin)
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint wavelength range: 3632.2 Angstrom, 5760.5 Angstrom (AA)
# [pykoala] 2025/03/31 18:06|INFO> WCS array shape: (2047, 52, 99) [wave, ra, dec]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Using input WCS
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising GaussianKernel
#  Scale: 1.0 arcsec (pixels)
#  Truncation radius: 3.0 (3.0 arcsec px)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising new Cube with dimensions: (2047, 99, 52)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Output Cube units: adu / s
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Cubing input RSS set
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Interpolating RSS to cube
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Fibres will be interpolated to new wavelength grid
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'angstrom' -> 'Angstrom'. [astropy.wcs.wcs]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Stacking individual cubes using mad_clipping
# [pykoala] 2025/03/31 18:06|INFO> Only one cube to stack
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Offset found (ra, dec): 3.2793772313880254-2.7156414784933247 (arcsec)
# [pykoala] 2025/03/31 18:06|INFO> [Registration]  Data provided in RSS format --> creating a dummy datacube
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint center: 101.3038 deg, 2.1375 deg
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint Fov: 0.43 arcmin, 0.82 arcmin (arcmin)
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint wavelength range: 3632.2 Angstrom, 5760.5 Angstrom (AA)
# [pykoala] 2025/03/31 18:06|INFO> WCS array shape: (2047, 52, 99) [wave, ra, dec]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Using input WCS
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising GaussianKernel
#  Scale: 1.0 arcsec (pixels)
#  Truncation radius: 3.0 (3.0 arcsec px)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising new Cube with dimensions: (2047, 99, 52)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Output Cube units: adu / s
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Cubing input RSS set
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Interpolating RSS to cube
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Fibres will be interpolated to new wavelength grid
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'angstrom' -> 'Angstrom'. [astropy.wcs.wcs]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Stacking individual cubes using mad_clipping
# [pykoala] 2025/03/31 18:06|INFO> Only one cube to stack
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Offset found (ra, dec): 3.9552962741083775-2.7864481744494185 (arcsec)
# /home/pcorchoc/Develop/koala/src/pykoala/plotting/utils.py:611: UserWarning: Adding colorbar to a different Figure <Figure size 1200x400 with 3 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   plt.colorbar(mappable, cax=cax)
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Applying correction to RSS
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Applying correction to RSS
# [pykoala.correction.Astrometry] 2025/03/31 18:06|INFO> Applying correction to RSS
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint center: 101.3054 deg, 2.1371 deg
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint Fov: 0.49 arcmin, 0.87 arcmin (arcmin)
# [pykoala] 2025/03/31 18:06|INFO> Combined footprint wavelength range: 3632.2 Angstrom, 5760.5 Angstrom (AA)
# [pykoala] 2025/03/31 18:06|INFO> WCS array shape: (2047, 58, 105) [wave, ra, dec]
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Using input WCS
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising GaussianKernel
#  Scale: 1.0 arcsec (pixels)
#  Truncation radius: 3.0 (3.0 arcsec px)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Initialising new Cube with dimensions: (2047, 105, 58)
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Output Cube units: adu / s
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> QC plots will be generated during cube production
# [pykoala.CubeInterp] 2025/03/31 18:06|INFO> Cubing input RSS set
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Interpolating RSS to cube
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units:
#   'angstrom' -> 'Angstrom'. [astropy.wcs.wcs]
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Fibres will be interpolated to new wavelength grid
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Interpolating RSS to cube
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Fibres will be interpolated to new wavelength grid
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Interpolating RSS to cube
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Fibres will be interpolated to new wavelength grid
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Stacking individual cubes using mad_clipping
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/astropy/units/quantity.py:658: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/astropy/units/quantity.py:658: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/pcorchoc/Develop/koala/src/pykoala/cubing.py:128: RuntimeWarning: invalid value encountered in divide
#   w = np.where(norm > 0, w / norm, np.nan)
# [pykoala.CubeInterp] 2025/03/31 18:07|INFO> Producing quality assessment plots
# Mean exposure time (s):  18.74001152293851
# [pykoala] 2025/03/31 18:07|INFO> [QCPLOT] Cube QC plot for: HILT600
# [pykoala.correction.TelluricCorretion] 2025/03/31 18:07|INFO> Applying telluric correction
# [pykoala] 2025/03/31 18:07|INFO> ----------------------------------------
# Automatic calibration process for HILT600
# ----------------------------------------
#
# [pykoala] 2025/03/31 18:07|INFO> Extracting stellar flux from data
# [pykoala] 2025/03/31 18:07|INFO> Extracting star flux.
#  -> Wavelength range=None
#  -> Wavelength window=5
#
# [pykoala] 2025/03/31 18:07|INFO> Extracting flux from input Cube
# [pykoala] 2025/03/31 18:07|INFO> ...Fitting wavelength chuncks...
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/astropy/units/quantity.py:658: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/pcorchoc/Develop/koala/src/pykoala/corrections/flux_calibration.py:406: OptimizeWarning: Covariance of the parameters could not be estimated
#   r2_dummy.to_value("arcsec^2").mean(), 1.0]
# adu / s
# [pykoala] 2025/03/31 18:07|INFO> Making stellar flux extraction plot
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /home/pcorchoc/Develop/koala/src/pykoala/corrections/flux_calibration.py:460: RuntimeWarning: divide by zero encountered in log10
#   ax.set_title("Median intensity")
# /home/pcorchoc/Develop/koala/src/pykoala/corrections/flux_calibration.py:460: RuntimeWarning: invalid value encountered in log10
#   ax.set_title("Median intensity")
# [pykoala] 2025/03/31 18:07|INFO> Interpolating template to observed wavelength
# [pykoala] 2025/03/31 18:07|INFO> Loading template spectra
# [pykoala] 2025/03/31 18:07|INFO> WARNING: More than one file found
# [pykoala] 2025/03/31 18:07|INFO> Input name fhilt600, matches ['fhilt600' 'fhilt600']
# Selecting fhilt600
# [pykoala] 2025/03/31 18:07|INFO> Computing spectrophotometric response
# [pykoala] 2025/03/31 18:07|INFO> Masking lines
# [pykoala] 2025/03/31 18:07|INFO> Masking zeros
# [pykoala.correction.FluxCalibration] 2025/03/31 18:07|INFO> Initialising Flux Calibration (Spectral Throughput)
# [pykoala] 2025/03/31 18:07|INFO> Mastering response function
