# %%
from koala_drpipe.reader import koala_rss
from koala_drpipe.instrument_config import ObservationConfig

# %% [markdown]
# The configuration can be read from raw or 2dfdr-processed frames

# %%
raw_observation_configuration = ObservationConfig.from_fits("/home/pcorchoc/Research/obs_data/HI-KIDS/obs_runs/night_20160114/ccd_1/580V_4800/sci/14jan10015red.fits")
reduced_observation_configuration = ObservationConfig.from_fits("/home/pcorchoc/Research/obs_data/HI-KIDS/raw/20180227/ccd_1/27feb10013.fits")

# %%
print("    Configuration of raw file \n")
raw_observation_configuration.show_config()
print("\n\n    Configuration of 2dfdr-processed file \n")
reduced_observation_configuration.show_config()
# Out:
#     Configuration of raw file
#
# [pykoala] 2025/03/28 18:45|INFO> Observation configuration:
#  - Mean Ra/Dec: 29.1277876269798/-31.3493995908298
#  - UT start: 2016-01-14 08:27:54
#  - UT end: 2016-01-14 08:37:54
#  - Is raw file: False
#  - 2dfdr version: ?
# [pykoala] 2025/03/28 18:45|INFO> AAOMega configuration:
#  - Arm: bl
#  - Grating: 580V
#  - Dichroic: X5700
#  - Exp. Time: 600.0
# [pykoala] 2025/03/28 18:45|INFO> KOALA configuration:
#  - Mode: N/A
#  - Rotator PA: 90.04673558567
#
#
#     Configuration of 2dfdr-processed file
#
# [pykoala] 2025/03/28 18:45|INFO> Observation configuration:
#  - Mean Ra/Dec: 79.2819727714532/-30.5003265234368
#  - UT start: 2018-02-27 08:26:33
#  - UT end: 2018-02-27 08:26:35
#  - Is raw file: True
#  - 2dfdr version: None
# [pykoala] 2025/03/28 18:45|INFO> AAOMega configuration:
#  - Arm: bl
#  - Grating: 580V
#  - Dichroic: X5700
#  - Exp. Time: 1.8
# [pykoala] 2025/03/28 18:45|INFO> KOALA configuration:
#  - Mode: N/A
# ...
